# %%
#| default_exp models.__init__

# %%
#| export
from peshbeen.models.ml_forecaster import ml_forecaster
from peshbeen.models.var import var
from peshbeen.models.ms_arr import ms_arr
from peshbeen.models.ml_mv_forecaster import ml_mv_forecaster
from peshbeen.models.ms_var import ms_var
from peshbeen.models.arima import arima
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 #| export
# ----> 2 from peshbeen.models.ml_forecaster import ml_forecaster
#       3 from peshbeen.models.var import var
#       4 from peshbeen.models.ms_arr import ms_arr
#
# File ~/Desktop/my_desk/peshbeen/peshbeen/models/__init__.py:7
#       4 __all__ = []
#       6 # %% ../../nbs/modules/02_models/00_index.ipynb #313a58b5
# ----> 7 from .ml_forecaster import ml_forecaster
#       8 from .var import var
#       9 from .ms_arr import ms_arr
#
# File ~/Desktop/my_desk/peshbeen/peshbeen/models/ml_forecaster.py:7
#       5 from typing import List, Dict, Optional, Callable, Tuple, Any, Union
#       6 from xml.parsers.expat import model
# ----> 7 from sklearn.base import clone
#       8 from tabnanny import verbose
#       9 import numpy as np
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)    111     "compose",
#     112 ]
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/base.py:20
#      18 from sklearn.exceptions import InconsistentVersionWarning
#      19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#      22 from sklearn.utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _convert_to_numpy,
#      27     _is_numpy_namespace,
#      28     _max_precision_float_dtype,
#      29     get_namespace,
#      30     get_namespace_and_device,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df, is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/_array_api.py:20
#      18 from sklearn.externals.array_api_compat import numpy as np_compat
#      19 from sklearn.utils._dataframe import is_df_or_series
# ---> 20 from sklearn.utils.fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/sklearn/utils/fixes.py:19
#      16 import scipy.stats
#      18 try:
# ---> 19     import pandas as pd
#      20 except ImportError:
#      21     pd = None
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
#      70     isna,
#      71     isnull,
#      72     notna,
#      73     notnull,
#      74     # indexes
#      75     Index,
#      76     CategoricalIndex,
#      77     RangeIndex,
#      78     MultiIndex,
#      79     IntervalIndex,
#      80     TimedeltaIndex,
#      81     DatetimeIndex,
#      82     PeriodIndex,
#      83     IndexSlice,
#      84     # tseries
#      85     NaT,
#      86     Period,
#      87     period_range,
#      88     Timedelta,
#      89     timedelta_range,
#      90     Timestamp,
#      91     date_range,
#      92     bdate_range,
#      93     Interval,
#      94     interval_range,
#      95     DateOffset,
#      96     # conversion
#      97     to_numeric,
#      98     to_datetime,
#      99     to_timedelta,
#     100     # misc
#     101     Flags,
#     102     Grouper,
#     103     factorize,
#     104     unique,
#     105     value_counts,
#     106     NamedAgg,
#     107     array,
#     108     Categorical,
#     109     set_eng_float_format,
#     110     Series,
#     111     DataFrame,
#     112 )
#     114 from pandas.core.dtypes.dtypes import SparseDtype
#     116 from pandas.tseries.api import infer_freq
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/pandas/core/api.py:9
#       1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
# ----> 9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#      12     DatetimeTZDtype,
#      13     IntervalDtype,
#      14     PeriodDtype,
#      15 )
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26     value_counts,
#      27 )
#
# File ~/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/pandas/core/dtypes/dtypes.py:24
#      21 import numpy as np
#      22 import pytz
# ---> 24 from pandas._libs import (
#      25     lib,
#      26     missing as libmissing,
#      27 )
#      28 from pandas._libs.interval import Interval
#      29 from pandas._libs.properties import cache_readonly
#
# File pandas/_libs/lib.pyx:86, in init pandas._libs.lib()
#
# File <frozen importlib._bootstrap>:1411, in _handle_fromlist(module, fromlist, import_, recursive)
#    1402 """Figure out what __import__ should return.
#    1403
#    1404 The import_ parameter is a callable which takes the name of module to
#    (...)   1407
#    1408 """
#    1409 # The hell that is fromlist ...
#    1410 # If a package was imported, try to import stuff from fromlist.
# -> 1411 for x in fromlist:
#    1412     if not isinstance(x, str):
#    1413         if recursive:
#
# AttributeError: partially initialized module 'pandas' from '/Users/aslanm/Desktop/my_desk/peshbeen/.venv/lib/python3.14/site-packages/pandas/__init__.py' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
